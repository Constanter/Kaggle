# %% [markdown]
# # 1) Import TensorFlow and other libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# # 2) Download and explore the dataset

# %%
import pathlib
data_dir = "../input/flowers-recognition/flowers/flowers"

data_dir = pathlib.Path(data_dir)
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 4323

# %%
roses = list(data_dir.glob("rose/*"))
PIL.Image.open(str(roses[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x135 at 0x7F610BAD9610>

# %%
tulips = list(data_dir.glob('tulip/*'))
PIL.Image.open(str(tulips[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x273 at 0x7F610BA16310>

# %%
batch_size = 32
img_height = 180
img_width = 180

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=42,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=41,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4323 files belonging to 5 classes.
# Using 3459 files for training.
# Found 4323 files belonging to 5 classes.
# Using 864 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']

# %% [markdown]
# # 3) Visualize the data

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # 4) Create the model

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
num_classes = 5

model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=4, min_lr=0.0001)
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=6)

# %%
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[reduce_lr,early_stop]
)
# Out:
# Epoch 1/50
# 109/109 [==============================] - 28s 63ms/step - loss: 1.5628 - accuracy: 0.3553 - val_loss: 1.1118 - val_accuracy: 0.5255
# Epoch 2/50
# 109/109 [==============================] - 4s 40ms/step - loss: 1.1101 - accuracy: 0.5384 - val_loss: 1.0223 - val_accuracy: 0.5833
# Epoch 3/50
# 109/109 [==============================] - 4s 41ms/step - loss: 0.9919 - accuracy: 0.6166 - val_loss: 0.9360 - val_accuracy: 0.6238
# Epoch 4/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.8912 - accuracy: 0.6388 - val_loss: 1.0023 - val_accuracy: 0.6088
# Epoch 5/50
# 109/109 [==============================] - 4s 41ms/step - loss: 0.8401 - accuracy: 0.6729 - val_loss: 0.7873 - val_accuracy: 0.6921
# Epoch 6/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.8021 - accuracy: 0.6951 - val_loss: 0.7734 - val_accuracy: 0.6933
# Epoch 7/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.7756 - accuracy: 0.7036 - val_loss: 0.7641 - val_accuracy: 0.6991
# Epoch 8/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.7787 - accuracy: 0.6963 - val_loss: 0.6806 - val_accuracy: 0.7303
# Epoch 9/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.6943 - accuracy: 0.7403 - val_loss: 0.7467 - val_accuracy: 0.7118
# Epoch 10/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.6949 - accuracy: 0.7319 - val_loss: 0.6911 - val_accuracy: 0.7338
# Epoch 11/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.6546 - accuracy: 0.7536 - val_loss: 0.6178 - val_accuracy: 0.7627
# Epoch 12/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.6379 - accuracy: 0.7594 - val_loss: 0.6051 - val_accuracy: 0.7766
# Epoch 13/50
# 109/109 [==============================] - 4s 41ms/step - loss: 0.5960 - accuracy: 0.7689 - val_loss: 0.5825 - val_accuracy: 0.7789
# Epoch 14/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.5989 - accuracy: 0.7761 - val_loss: 0.5364 - val_accuracy: 0.8056
# Epoch 15/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.5613 - accuracy: 0.7937 - val_loss: 0.5431 - val_accuracy: 0.7975
# Epoch 16/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.5484 - accuracy: 0.7876 - val_loss: 0.4964 - val_accuracy: 0.8137
# Epoch 17/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.5216 - accuracy: 0.7959 - val_loss: 0.4657 - val_accuracy: 0.8229
# Epoch 18/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.5080 - accuracy: 0.8076 - val_loss: 0.4839 - val_accuracy: 0.8183
# Epoch 19/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.4803 - accuracy: 0.8037 - val_loss: 0.4637 - val_accuracy: 0.8310
# Epoch 20/50
# 109/109 [==============================] - 4s 41ms/step - loss: 0.4943 - accuracy: 0.8073 - val_loss: 0.4400 - val_accuracy: 0.8461
# Epoch 21/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.4830 - accuracy: 0.8143 - val_loss: 0.4797 - val_accuracy: 0.8299
# Epoch 22/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.4497 - accuracy: 0.8222 - val_loss: 0.4050 - val_accuracy: 0.8507
# Epoch 23/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.4470 - accuracy: 0.8308 - val_loss: 0.4069 - val_accuracy: 0.8461
# Epoch 24/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.4148 - accuracy: 0.8470 - val_loss: 0.4262 - val_accuracy: 0.8403
# Epoch 25/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.3905 - accuracy: 0.8563 - val_loss: 0.3706 - val_accuracy: 0.8646
# Epoch 26/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.3472 - accuracy: 0.8673 - val_loss: 0.3984 - val_accuracy: 0.8634
# Epoch 27/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.3832 - accuracy: 0.8447 - val_loss: 0.3821 - val_accuracy: 0.8634
# Epoch 28/50
# 109/109 [==============================] - 4s 41ms/step - loss: 0.3238 - accuracy: 0.8798 - val_loss: 0.3287 - val_accuracy: 0.8831
# Epoch 29/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.3102 - accuracy: 0.8854 - val_loss: 0.3405 - val_accuracy: 0.8796
# Epoch 30/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.3269 - accuracy: 0.8736 - val_loss: 0.3415 - val_accuracy: 0.8819
# Epoch 31/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.3003 - accuracy: 0.8889 - val_loss: 0.3960 - val_accuracy: 0.8692
# Epoch 32/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.2957 - accuracy: 0.8779 - val_loss: 0.3419 - val_accuracy: 0.8646
# Epoch 33/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.2426 - accuracy: 0.9200 - val_loss: 0.2791 - val_accuracy: 0.8912
# Epoch 34/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.2281 - accuracy: 0.9187 - val_loss: 0.2555 - val_accuracy: 0.9005
# Epoch 35/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.1769 - accuracy: 0.9343 - val_loss: 0.2580 - val_accuracy: 0.9086
# Epoch 36/50
# 109/109 [==============================] - 4s 41ms/step - loss: 0.1900 - accuracy: 0.9376 - val_loss: 0.2605 - val_accuracy: 0.9132
# Epoch 37/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.1806 - accuracy: 0.9373 - val_loss: 0.2430 - val_accuracy: 0.9120
# Epoch 38/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.1522 - accuracy: 0.9525 - val_loss: 0.2475 - val_accuracy: 0.9086
# Epoch 39/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.1763 - accuracy: 0.9318 - val_loss: 0.2630 - val_accuracy: 0.9120
# Epoch 40/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.1816 - accuracy: 0.9392 - val_loss: 0.2446 - val_accuracy: 0.9144
# Epoch 41/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.1763 - accuracy: 0.9371 - val_loss: 0.2601 - val_accuracy: 0.9144
# Epoch 42/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.1494 - accuracy: 0.9428 - val_loss: 0.2385 - val_accuracy: 0.9167
# Epoch 43/50
# 109/109 [==============================] - 4s 41ms/step - loss: 0.1708 - accuracy: 0.9389 - val_loss: 0.2512 - val_accuracy: 0.9132
# Epoch 44/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.1655 - accuracy: 0.9451 - val_loss: 0.2522 - val_accuracy: 0.9155
# Epoch 45/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.1393 - accuracy: 0.9528 - val_loss: 0.2411 - val_accuracy: 0.9120
# Epoch 46/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.1577 - accuracy: 0.9433 - val_loss: 0.2419 - val_accuracy: 0.9167
# Epoch 47/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.1298 - accuracy: 0.9587 - val_loss: 0.2319 - val_accuracy: 0.9259
# Epoch 48/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.1339 - accuracy: 0.9533 - val_loss: 0.2526 - val_accuracy: 0.9155
# Epoch 49/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.1452 - accuracy: 0.9506 - val_loss: 0.2467 - val_accuracy: 0.9178
# Epoch 50/50
# 109/109 [==============================] - 4s 40ms/step - loss: 0.1296 - accuracy: 0.9546 - val_loss: 0.2350 - val_accuracy: 0.9248

# %% [markdown]
# # 5) Visualize training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # 6) Test model

# %%
sunflower_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/592px-Red_sunflower.jpg"
sunflower_path = tf.keras.utils.get_file('Red_sunflower', origin=sunflower_url)

img = keras.preprocessing.image.load_img(
    sunflower_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/592px-Red_sunflower.jpg
# 122880/117948 [===============================] - 0s 0us/step
# This image most likely belongs to sunflower with a 100.00 percent confidence.
